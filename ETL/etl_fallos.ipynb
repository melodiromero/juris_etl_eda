# %% [markdown]
# # Extracción, transformación y carga de los fallos

# %% [markdown]
# ## Extracción de los datos

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Conexión a la base de datos
engine = create_engine('mysql+pymysql://civil7:v6TCV8KUFtqCXKnv@10.0.52.250/c1jurisprudencia')

# %%
engine = create_engine('mysql+pymysql://root:sistemas1@localhost/c1jurisprudencia')

# %%
# FALLOS
# Consulta SQL para seleccionar los datos que deseas extraer
query = "SELECT * FROM fallos"

# Conecta a la base de datos
connection = engine.raw_connection()
cursor = connection.cursor()

# Ejecuta la consulta y carga los resultados en un DataFrame
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Cierra el cursor y la conexión
cursor.close()
connection.close()

# %%
df.head()
# Out:
#    Id_Fallos  NroFallo  FechaFallo  Organismo  \
# 0         42      9966  10/03/2005          2
# 1          2     13453  02/02/2009          2
# 2          3     13455  02/02/2009          2
# 3          4     13457  02/02/2009          2
# 4          5     13459  03/02/2009          2
#
#                                               Partes  \
# 0  TELECOM ARG. S.A. S/ ACCION AUTONOMA DE NULIDA...
# 1    CAZAL CARLOS ALBERTO C/ VEGA MARIO S/ EJECUTIVO
# 2  INCIDENTE DE ESTIMACION DE HONORARIOS Y MEDIDA...
# 3  BIBOLINI, JOSE MARIA ANGEL S/ SUCESORIO ‘INCID...
# 4  AGUAS DE FORMOSA C/ FRIGORIFICO NORTE S.R.L. S...
#
#                                                Fallo Tipo Resolucion  \
# 0  V I S T O: \r\nEstos autos caratulados: “TELEC...
# 1  V I S T O:\r\nEstos autos caratulados: “CAZAL ...
# 2  V I S T O:\r\nEstos autos caratulados: “INCIDE...
# 3  V I S T O:\r\nEstos autos caratulados: “BIBOLI...
# 4  V I S T O:\r\nEstos autos caratulados: “AGUAS ...
#
# ...

# %% [markdown]
# ## Transformación de los datos

# %% [markdown]
# ### Descripción de los datos

# %%
registros   = df.shape[0]
registros
# Out:
# 18108

# %%
columnas    = df.shape[1]
columnas
# Out:
# 11

# %%
df.columns
# Out:
# Index(['Id_Fallos', 'NroFallo', 'FechaFallo', 'Organismo', 'Partes', 'Fallo',
#        'Tipo', 'Resolucion', 'Expediente', 'Fecha', 'fecord'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18108 entries, 0 to 18107
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id_Fallos   18108 non-null  int64
#  1   NroFallo    18108 non-null  int64
#  2   FechaFallo  18108 non-null  object
#  3   Organismo   18108 non-null  int64
#  4   Partes      18108 non-null  object
#  5   Fallo       18108 non-null  object
#  6   Tipo        18108 non-null  object
#  7   Resolucion  16000 non-null  object
#  8   Expediente  16000 non-null  object
#  9   Fecha       18108 non-null  object
#  10  fecord      18108 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.5+ MB

# %%
df['Partes'] = df['Partes'].astype(str)
df['Fallo'] = df['Fallo'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18108 entries, 0 to 18107
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id_Fallos   18108 non-null  int64
#  1   NroFallo    18108 non-null  int64
#  2   FechaFallo  18108 non-null  object
#  3   Organismo   18108 non-null  int64
#  4   Partes      18108 non-null  object
#  5   Fallo       18108 non-null  object
#  6   Tipo        18108 non-null  object
#  7   Resolucion  16000 non-null  object
#  8   Expediente  16000 non-null  object
#  9   Fecha       18108 non-null  object
#  10  fecord      18108 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#           Id_Fallos       NroFallo     Organismo
# count  18108.000000   18108.000000  18108.000000
# mean    9148.388392   10719.418158      9.095262
# std     5277.864381    6576.987286     12.047738
# min        2.000000       1.000000      0.000000
# 25%     4548.750000    5093.750000      2.000000
# 50%     9184.500000   11502.500000      2.000000
# 75%    13721.250000   15723.250000      9.000000
# max    18250.000000  170003.000000     37.000000

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# #### Valores nulos

# %%
for columna in df.columns:
    print(f"Columna: {columna}")
    
    # Encuentra valores nulos en la columna
    valores_nulos = df[columna].isnull().sum()
    print(f"Valores nulos: {valores_nulos}")
     
    # Imprime una línea en blanco para separar las columnas
    print("\n")
# Out:
# Columna: Id_Fallos
# Valores nulos: 0
#
#
# Columna: NroFallo
# Valores nulos: 0
#
#
# Columna: FechaFallo
# Valores nulos: 0
#
#
# Columna: Organismo
# Valores nulos: 0
#
#
# Columna: Partes
# Valores nulos: 0
#
#
# Columna: Fallo
# Valores nulos: 0
#
#
# Columna: Tipo
# Valores nulos: 0
#
#
# Columna: Resolucion
# Valores nulos: 2108
#
#
# Columna: Expediente
# Valores nulos: 2108
#
#
# Columna: Fecha
# Valores nulos: 0
#
#
# Columna: fecord
# Valores nulos: 0

# %% [markdown]
# #### Registros duplicados

# %%
# Encuentra valores duplicados en la columna
valores_duplicados = df.duplicated().sum()
print(f"Valores duplicados: {valores_duplicados}")
# Out:
# Valores duplicados: 0

# %% [markdown]
# #### Registros con valores vacios

# %%
for columna in df.columns:
    print(f"Columna: {columna}")
    
    # Encuentra valores vacios en la columna
    valores_nulos = df.loc[df[columna] == '']   
    
    if valores_nulos.empty:
        print(f"Valores vacios: 0")
    else:
        print(f"Valores vacios ({len(valores_nulos)}): ")
        print("\n")
        print(valores_nulos)

     
    # Imprime una línea en blanco para separar las columnas
    print("\n")
# Out:
# Columna: Id_Fallos
# Valores vacios: 0
#
#
# Columna: NroFallo
# Valores vacios: 0
#
#
# Columna: FechaFallo
# Valores vacios: 0
#
#
# Columna: Organismo
# Valores vacios: 0
#
#
# Columna: Partes
# Valores vacios (12):
#
#
#        Id_Fallos  NroFallo  FechaFallo  Organismo Partes  \
# 718          722     12946  03/07/2008          2
# 3277        3287      9542  27/04/2011          1
# 8029        8136     10778  11/03/2015         31
# 8030        8137     10779  11/03/2015         31
# 9275        9375      9251  14/10/2015          4
# 10458      10555        13      //2000          0
# 11847      11952     18733      //2000          0
# 14432      14571     16173      //2000          0
# 14794      14933     19739      //2000          0
# 15006      15145     19810  26/10/2020          2
# 15016      15155     19820      //2000          0
# 15529      15663      5681  10/08/2021         32
#
#                                                    Fallo Tipo Resolucion  \
# 718
# ...

# %% [markdown]
# #### Registros con mismo numero y organismo

# %%
# Agrupa por NroFallo y Organismo y obtén los grupos que tienen más de un fallo
grouped = df.groupby(['NroFallo', 'Organismo'])
duplicates = grouped.filter(lambda group: len(group) > 1)

# Muestra los detalles de los fallos con el mismo número de fallo y organismo
print(duplicates)
# Out:
#        Id_Fallos  NroFallo  FechaFallo  Organismo  \
# 0             42      9966  10/03/2005          2
# 21            22      8736  25/03/2004          2
# 22            23      8736  25/03/2004          2
# 27            28      9073  03/06/2004          2
# 39            40      9793  16/12/2004          2
# ...          ...       ...         ...        ...
# 17653      17796         3  10/02/2023          8
# 17654      17797         8  06/03/2023          8
# 17655      17798        54  27/10/2022          8
# 17656      17799        58  18/11/2022          8
# 17673      17816        54  16/03/2020          9
#
#                                                   Partes  \
# 0      TELECOM ARG. S.A. S/ ACCION AUTONOMA DE NULIDA...
# 21     BANCO HIPOTECARIO S.A. C/ ROSENDE, HUGO OSCAR ...
# 22     BANCO HIPOTECARIO S.A. C/ ROSENDE, HUGO OSCAR ...
# 27     DOMINGUEZ, SILVIA NOELIA C/ VILLENA JORGE Y/U ...
# 39     BRIZUELA, TOMÁS ALARICO C/SCOFFIELD, JOSE JOAQ...
# ...

# %%
# Agrupa por NroFallo y Organismo y cuenta cuántos registros hay en cada grupo
count_fallos = df.groupby(['NroFallo', 'Organismo']).size().reset_index(name='Cantidad de Fallos')

# Filtra los grupos que tienen más de un fallo
count_fallos = count_fallos[count_fallos['Cantidad de Fallos'] > 1]

# %%
count_fallos
# Out:
#        NroFallo  Organismo  Cantidad de Fallos
# 0             1          6                   8
# 1             1          7                  13
# 2             1          8                  12
# 8             2          6                   8
# 9             2          7                  13
# ...         ...        ...                 ...
# 15187     20013          2                   2
# 15212     20042          2                   2
# 15371     20204          2                   2
# 15480     20315          2                   2
# 15949     20786          2                   2
#
# [1033 rows x 3 columns]

# %%
# Agrupa por NroFallo y Organismo y obtén los grupos que tienen más de un fallo
grouped = df.groupby(['NroFallo', 'Organismo'])
duplicates = grouped.filter(lambda group: len(group) > 1)

# Muestra los detalles de los fallos con el mismo número de fallo y organismo
print(duplicates)
# Out:
#       Id_Fallos  NroFallo  FechaFallo  Organismo  \
# 0            42      9966  10/03/2005          2
# 21           22      8736  25/03/2004          2
# 22           23      8736  25/03/2004          2
# 27           28      9073  03/06/2004          2
# 39           40      9793  16/12/2004          2
# ...         ...       ...         ...        ...
# 1364       1366     14274  15/03/2010          2
# 1496       1506      3213  11/03/2009          1
# 1497       1507      3213  11/03/2009          1
# 1504       1514      3220  20/04/2009          1
# 1514       1524      3220  20/04/2009          1
#
#                                                  Partes  \
# 0     TELECOM ARG. S.A. S/ ACCION AUTONOMA DE NULIDA...
# 21    BANCO HIPOTECARIO S.A. C/ ROSENDE, HUGO OSCAR ...
# 22    BANCO HIPOTECARIO S.A. C/ ROSENDE, HUGO OSCAR ...
# 27    DOMINGUEZ, SILVIA NOELIA C/ VILLENA JORGE Y/U ...
# 39    BRIZUELA, TOMÁS ALARICO C/SCOFFIELD, JOSE JOAQ...
# ...

# %% [markdown]
# ### Campo Fecha

# %%
# Convierte el campo "FechaFallo" a un objeto de fecha
df['FechaFallo'] = pd.to_datetime(df['FechaFallo'], format='%d/%m/%Y', errors='coerce')

# La columna "FechaFallo" ahora contiene objetos de fecha
print(df['FechaFallo'])
# Out:
# 0       2005-03-10
# 1       2009-02-02
# 2       2009-02-02
# 3       2009-02-02
# 4       2009-02-03
#            ...
# 18103   2023-09-29
# 18104   2023-09-07
# 18105   2023-05-12
# 18106   2021-08-09
# 18107   2023-03-14
# Name: FechaFallo, Length: 18108, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18108 entries, 0 to 18107
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id_Fallos   18108 non-null  int64
#  1   NroFallo    18108 non-null  int64
#  2   FechaFallo  18097 non-null  datetime64[ns]
#  3   Organismo   18108 non-null  int64
#  4   Partes      18108 non-null  object
#  5   Fallo       18108 non-null  object
#  6   Tipo        18108 non-null  object
#  7   Resolucion  16000 non-null  object
#  8   Expediente  16000 non-null  object
#  9   Fecha       18108 non-null  object
#  10  fecord      18108 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 1.5+ MB
